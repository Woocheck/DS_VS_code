# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_excel("PL_GEN_WIATR_20211103_20211202_20211203070532.xlsm", "PL_GEN_WIATR_20211103_20211202_", index_col= 'Data' )
df
# Out:
#             Godzina  Generacja źródeł wiatrowych  \
# Data
# 2021-11-03        1                      875.650
# 2021-11-03        2                      928.563
# 2021-11-03        3                      947.763
# 2021-11-03        4                     1000.875
# 2021-11-03        5                     1076.338
# ...             ...                          ...
# 2021-12-02       20                     4681.625
# 2021-12-02       21                     4261.938
# 2021-12-02       22                     3831.625
# 2021-12-02       23                     3345.100
# 2021-12-02       24                     3083.675
#
#             Generacja źródeł fotowoltaicznych
# Data
# 2021-11-03                                0.0
# 2021-11-03                                0.0
# 2021-11-03                                0.0
# 2021-11-03                                0.0
# 2021-11-03                                0.0
# ...                                       ...
# ...

# %%
plt.figure()

df.plot()
# Out:
# <AxesSubplot:>
